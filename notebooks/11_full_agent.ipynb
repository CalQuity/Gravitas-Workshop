# %% [markdown]
# # 7. Complete Research Agent
#
# **Goal:** Use the finished agent assembled in agent.py.

# %%
from pathlib import Path
import os
import sys

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "agent.py").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from agno.agent import Agent
from agno.models.openai import OpenAIChat
from embedding import load_settings

RUN_LIVE = True
settings = load_settings()
model = OpenAIChat(
    id=settings["openrouter_model"],
    api_key=settings["openrouter_api_key"],
    base_url="https://openrouter.ai/api/v1",
)
print("Ready. Live model calls:", RUN_LIVE)
# Out:
# Ready. Live model calls: True

# %%
async def ask(workshop_agent, question, session_id=None):
    if not RUN_LIVE:
        return "Skipped. Set RUN_LIVE = True for a model call."
    response = await workshop_agent.arun(question, session_id=session_id)
    return response.content

# %%
from embedding import create_knowledge
from agent import create_agent

knowledge = create_knowledge()
research_agent = create_agent()
print(research_agent.name)
print(await ask(
    research_agent,
    "Compare document revenue with current HCLTech OHLCV data for past 5 days. Also fetch the latest news affecting the stock movement.",
    "team-07-final",
))
# Out:
# Gravitas Student Agent
#
#
#
#
# ## HCLTech — 5-Day OHLCV vs Document Revenue + Latest News
#
# ---
#
# ### 1️⃣ OHLCV Snapshot – Past 5 Trading Days (NSE: HCLTECH)
# Latest market day: **Thursday, 16 Sep 2026**
#
# | Date | Open | High | Low | Close | Volume |
# |---|---|---|---|---|---|
# | **Sep 14** (Sat – prev. trading day) | — | — | — | **₹1,206.10** | — |
# | **Sep 15** | ₹1,252.00 | ₹1,290.00 | ₹1,250.00 | **₹1,253.70** | **4,443,984** |
# | **Sep 16** | ₹1,262.50 | ₹1,284.60 | ₹1,244.90 | **₹1,253.00** | **3,048,581** |
# | **Sep 11** | ₹1,196.00 | ₹1,223.40 | ₹1,195.70 | **₹1,206.10** | **2,272,845** |
# | **Sep 10** | ₹1,224.80 | ₹1,237.00 | ₹1,196.90 | **₹1,207.00** | **2,197,859** |
#
# > **5-day price change:** +$4.60 (+3.8%) from Sep 10 close to Sep 16 close
# > *Weekend trading halt on 13–14 Sep 2026.*
#
# ---
#
# ### 2️⃣ Document Revenue Benchmark
# Source: **HCLTECH_Q1_FY27.pdf** (Conference Call, 13 Jul 2026) — Q1 FY27 ended 30 Jun 2026
#
# | Metric | Value (as filed) |
# |---|---|
# | **Total Revenue** | **US$3.65 Bn** |
# | **Services Revenue** | US$3.351 Bn |
# | **HCL Software Revenue** | US$313 Mn |
# | **YoY Growth (CC)** | +2.6% |
# | **Sequential QoQ** | −0.5% (seasonal AMJ) |
#
# ---
#
# ### 3️⃣ Recent News Shaping Stock Moves
#
# | Date | Headline | Impact |
# |---|---|---|
# | **15 Sep 2026** | Global AI leaders call for **slower, more cautious pace of AI development** → investors turned positive across IT. HCLTech **+6.75% intra-day** (India Today, Dynamite News). | Bullish sentiment — tech valuations support AI‐focussed stocks. |
# | **08 Sep 2026** | HCLTech launched **₹185 Cr Advanced Semiconductor Lab** in Bengaluru. Shares **fell 0.25%** on the day. | Neutral-to-negative: capital allocation scrutiny. |
# | **04 May 2026** | Expanded **Cornerstone Partnership as “Official AI Partner”** with MetLife Stadium, NY Giants & Jets. | Reinforcement of AI strategy. |
#
# ---
#
# ### 4️⃣ Quick Valuation Context (Market-to-Revenue)
#
# Using **₹1,253/share** and typical free float, the stock is trading at roughly **₹1.3–1.4 lakh crore market-cap** (price-to-revenue ≈ **1.0–1.2x** trailing 12M revenue).
#
# - Q1 FY27 revenue of **US$3.65 Bn** annualises to ~US$14.6 Bn.
# - At FY26 year-end price-to-revenue multiples for large IT peers have ranged 1.0–1.5x.
#
# ⇒ **Valuation sits near the low end of historical range,** potentially supported by accelerating AI-revenues (US$171 M Q1 FY27).
#
# ---
#
# ### 📌 Take-away
# While the latest **5-day rally (+3.8%)** coincides with a global reset on AI governance that has been interpreted as a tailwind for “quality AI-first” firms, the stock is still trading close to its historical revenue multiple floor—giving a revenue-centric floor of ~₹1.3 lakh crore market-cap.

# %% [markdown]
# ## Check
#
# Explain what capability this step added and which earlier limitation it fixes.
